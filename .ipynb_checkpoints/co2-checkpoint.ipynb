# %%
#!pip3 install mysql-connector     

import mysql.connector as sql
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

db_connection = sql.connect(host='10.0.0.21', database='co2_dev', user='co2user', password='c1m4V.21')
db_cursor = db_connection.cursor()
db_cursor.execute('select id, ppm1, ppm2, date  from datos where ppm2 <= 10 and ppm1 < 3000') #order by id desc limit 100000;

table_rows = db_cursor.fetchall()

df = pd.DataFrame(table_rows, columns=['id', 'ppm', 'sensor', 'date_time'])

df
# Out:
#               id   ppm  sensor           date_time
# 0              1   293       2 2021-10-13 13:12:18
# 1              2   298       2 2021-10-13 13:12:28
# 2              3   300       2 2021-10-13 13:12:39
# 3              4   299       2 2021-10-13 13:12:49
# 4              5   298       2 2021-10-13 13:12:59
# ...          ...   ...     ...                 ...
# 2881057  2881097   421      10 2022-04-18 16:32:53
# 2881058  2881098  1105       5 2022-04-18 16:33:19
# 2881059  2881099   363       9 2022-04-18 16:33:20
# 2881060  2881100   272       8 2022-04-18 16:33:22
# 2881061  2881101   419      10 2022-04-18 16:33:23
#
# [2881062 rows x 4 columns]

# %%
df.describe().applymap('{:,.2f}'.format) #.apply("{0:.5f}".format)
# Out:
#                  id           ppm        sensor
# count  2,881,062.00  2,881,062.00  2,881,062.00
# mean   1,440,548.64        389.96          6.27
# std      831,705.98        143.51          2.61
# min            1.00          0.00          1.00
# 25%      720,269.25        350.00          3.00
# 50%    1,440,534.50        368.00          7.00
# 75%    2,160,835.75        392.00          9.00
# max    2,881,101.00      2,827.00         10.00

# %%
# %%time
plt.figure(figsize=(20,15)) 
sns.lineplot(x=df['ppm'], y=df['sensor']) 
plt.xlabel('PPM') 
plt.ylabel('Sensor') 
plt.show()
# Out:
# CPU times: user 1min 10s, sys: 496 ms, total: 1min 10s
# Wall time: 1min 10s

# %%
plt.boxplot(df[['ppm']])
plt.show()

# %%
plt.figure(figsize=(13,5))
corr = df[['sensor','ppm']].corr()
corr
# Out:
#          sensor      ppm
# sensor  1.00000  0.07403
# ppm     0.07403  1.00000

# %%
ax = sns.heatmap(corr, vmin=-1.5, vmax=1.5, center=0, cmap=sns.diverging_palette(20, 220, n=200),square=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right');

# %%
# features into variables
sensores = df[['sensor']]
ppms = df[['ppm']]

# %%
# spliting data in train and test with train_test_split
sensor_treino, sensor_test, ppm_treino, ppm_test = train_test_split(sensores, ppms, test_size=0.2, random_state=42)

# %%
# ploting the correlation between features
plt.scatter(sensor_treino, ppm_treino, color='blue')
plt.xlabel('sensor')
plt.ylabel('ppm')
plt.show()
